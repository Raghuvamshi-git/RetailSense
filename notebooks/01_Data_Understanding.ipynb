# %%
import pandas as pd

# %%
calendar = pd.read_csv("../data/raw/calendar.csv")

# %%
calendar.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1

# %%
calendar.shape
# Out:
# (1969, 14)

# %%
calendar.columns
# Out:
# Index(['date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year', 'd',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI'],
#       dtype='str')

# %%
import pandas as pd

calendar = pd.read_csv("../data/raw/calendar.csv")

calendar.head()

calendar.shape

calendar.columns

calendar.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1969 entries, 0 to 1968
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1969 non-null   str
#  1   wm_yr_wk      1969 non-null   int64
#  2   weekday       1969 non-null   str
#  3   wday          1969 non-null   int64
#  4   month         1969 non-null   int64
#  5   year          1969 non-null   int64
#  6   d             1969 non-null   str
#  7   event_name_1  162 non-null    str
#  8   event_type_1  162 non-null    str
#  9   event_name_2  5 non-null      str
#  10  event_type_2  5 non-null      str
#  11  snap_CA       1969 non-null   int64
#  12  snap_TX       1969 non-null   int64
#  13  snap_WI       1969 non-null   int64
# dtypes: int64(7), str(7)
# memory usage: 215.5 KB

# %%
calendar.isnull().sum()
# Out:
# date               0
# wm_yr_wk           0
# weekday            0
# wday               0
# month              0
# year               0
# d                  0
# event_name_1    1807
# event_type_1    1807
# event_name_2    1964
# event_type_2    1964
# snap_CA            0
# snap_TX            0
# snap_WI            0
# dtype: int64

# %%
calendar.describe()
# Out:
#            wm_yr_wk         wday        month         year      snap_CA  \
# count   1969.000000  1969.000000  1969.000000  1969.000000  1969.000000
# mean   11347.086338     3.997461     6.325546  2013.288471     0.330117
# std      155.277043     2.001141     3.416864     1.580198     0.470374
# min    11101.000000     1.000000     1.000000  2011.000000     0.000000
# 25%    11219.000000     2.000000     3.000000  2012.000000     0.000000
# 50%    11337.000000     4.000000     6.000000  2013.000000     0.000000
# 75%    11502.000000     6.000000     9.000000  2015.000000     1.000000
# max    11621.000000     7.000000    12.000000  2016.000000     1.000000
#
#            snap_TX      snap_WI
# count  1969.000000  1969.000000
# mean      0.330117     0.330117
# std       0.470374     0.470374
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       1.000000     1.000000
# max       1.000000     1.000000

# %%
calendar.dtypes
# Out:
# date              str
# wm_yr_wk        int64
# weekday           str
# wday            int64
# month           int64
# year            int64
# d                 str
# event_name_1      str
# event_type_1      str
# event_name_2      str
# event_type_2      str
# snap_CA         int64
# snap_TX         int64
# snap_WI         int64
# dtype: object

# %%
calendar["date"] = pd.to_datetime(calendar["date"])

# %%
calendar.dtypes
# Out:
# date            datetime64[us]
# wm_yr_wk                 int64
# weekday                    str
# wday                     int64
# month                    int64
# year                     int64
# d                          str
# event_name_1               str
# event_type_1               str
# event_name_2               str
# event_type_2               str
# snap_CA                  int64
# snap_TX                  int64
# snap_WI                  int64
# dtype: object

# %%
calendar["date"].min(), calendar["date"].max()
# Out:
# (Timestamp('2011-01-29 00:00:00'), Timestamp('2016-06-19 00:00:00'))

# %%
calendar["date"] = pd.to_datetime(calendar["date"])

# %%
calendar["date"].min(), calendar["date"].max()
# Out:
# (Timestamp('2011-01-29 00:00:00'), Timestamp('2016-06-19 00:00:00'))

# %%
sales = pd.read_csv("../data/raw/sales_train_validation.csv")

# %%
sales.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  d_1907  d_1908  \
# 0       CA    0    0    0    0  ...       1       3       0       1       1
# 1       CA    0    0    0    0  ...       0       0       0       0       0
# 2       CA    0    0    0    0  ...       2       1       2       1       1
# 3       CA    0    0    0    0  ...       1       0       5       4       1
# 4       CA    0    0    0    0  ...       2       1       1       0       1
#
#    d_1909  d_1910  d_1911  d_1912  d_1913
# ...

# %%
sales.columns
# Out:
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'd_1',
#        'd_2', 'd_3', 'd_4',
#        ...
#        'd_1904', 'd_1905', 'd_1906', 'd_1907', 'd_1908', 'd_1909', 'd_1910',
#        'd_1911', 'd_1912', 'd_1913'],
#       dtype='str', length=1919)

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30490 entries, 0 to 30489
# Columns: 1919 entries, id to d_1913
# dtypes: int64(1913), str(6)
# memory usage: 446.4 MB

# %%
sales.isnull().sum()
# Out:
# id          0
# item_id     0
# dept_id     0
# cat_id      0
# store_id    0
#            ..
# d_1909      0
# d_1910      0
# d_1911      0
# d_1912      0
# d_1913      0
# Length: 1919, dtype: int64

# %%
sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
sales.dtypes
# Out:
# id            str
# item_id       str
# dept_id       str
# cat_id        str
# store_id      str
#             ...
# d_1909      int64
# d_1910      int64
# d_1911      int64
# d_1912      int64
# d_1913      int64
# Length: 1919, dtype: object

# %%
sales.describe()
# Out:
#                 d_1           d_2           d_3           d_4           d_5  \
# count  30490.000000  30490.000000  30490.000000  30490.000000  30490.000000
# mean       1.070220      1.041292      0.780026      0.833454      0.627944
# std        5.126689      5.365468      3.667454      4.415141      3.379344
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max      360.000000    436.000000    207.000000    323.000000    296.000000
#
#                 d_6           d_7           d_8           d_9          d_10  \
# count  30490.000000  30490.000000  30490.000000  30490.000000  30490.000000
# mean       0.958052      0.918662      1.244080      1.073663      0.838701
# ...

# %%
sales.memory_usage(deep=True)
# Out:
# Index          132
# id         2370420
# item_id    1882580
# dept_id    1760620
# cat_id     1699640
#             ...
# d_1909      243920
# d_1910      243920
# d_1911      243920
# d_1912      243920
# d_1913      243920
# Length: 1920, dtype: int64

# %%
sales.columns[:10]
# Out:
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'd_1',
#        'd_2', 'd_3', 'd_4'],
#       dtype='str')

# %%
sales.iloc[0]
# Out:
# id          HOBBIES_1_001_CA_1_validation
# item_id                     HOBBIES_1_001
# dept_id                         HOBBIES_1
# cat_id                            HOBBIES
# store_id                             CA_1
#                         ...
# d_1909                                  1
# d_1910                                  3
# d_1911                                  0
# d_1912                                  1
# d_1913                                  1
# Name: 0, Length: 1919, dtype: object

# %%
sales.iloc[0, 6:]
# Out:
# d_1       0
# d_2       0
# d_3       0
# d_4       0
# d_5       0
#          ..
# d_1909    1
# d_1910    3
# d_1911    0
# d_1912    1
# d_1913    1
# Name: 0, Length: 1913, dtype: object

# %%
sales.iloc[0, 6:].sum()
# Out:
# np.int64(600)

# %%
print(sales.iloc[0, 6:].max())
# Out:
# 5

# %%
sales.iloc[0, 6:].mean()
# Out:
# np.float64(0.31364349189754315)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,5))
plt.plot(sales.iloc[0, 6:])
plt.title("Daily Sales Trend of First Product")
plt.xlabel("Days")
plt.ylabel("Sales")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(sales.iloc[1, 6:])
plt.title("Daily Sales Trend of Second Product")
plt.xlabel("Days")
plt.ylabel("Sales")
plt.show()

# %%
prices = pd.read_csv("../data/raw/sell_prices.csv")

# %%
prices.head()
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26

# %%
prices.shape
# Out:
# (6841121, 4)

# %%
prices.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6841121 entries, 0 to 6841120
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   store_id    str
#  1   item_id     str
#  2   wm_yr_wk    int64
#  3   sell_price  float64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 208.8 MB

# %%
sales_long = pd.melt(
    sales,
    id_vars=["id","item_id","dept_id","cat_id","store_id","state_id"],
    var_name="d",
    value_name="sales"
)

# %%
sales_long.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d  sales
# 0       CA  d_1      0
# 1       CA  d_1      0
# 2       CA  d_1      0
# 3       CA  d_1      0
# 4       CA  d_1      0

# %%
sales_long.shape
# Out:
# (58327370, 8)

# %% [markdown]
# # 24. Merge Sales Data with Calendar Data

# %%
sales_calendar = sales_long.merge(
    calendar,
    on="d",
    how="left"
)

# %%
sales_calendar.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d  sales       date  wm_yr_wk  ... wday  month  year  \
# 0       CA  d_1      0 2011-01-29     11101  ...    1      1  2011
# 1       CA  d_1      0 2011-01-29     11101  ...    1      1  2011
# 2       CA  d_1      0 2011-01-29     11101  ...    1      1  2011
# 3       CA  d_1      0 2011-01-29     11101  ...    1      1  2011
# 4       CA  d_1      0 2011-01-29     11101  ...    1      1  2011
#
#    event_name_1 event_type_1 event_name_2 event_type_2 snap_CA  snap_TX  \
# ...

# %%
sales_calendar.shape
# Out:
# (58327370, 21)

# %%
sales_calendar["date"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 25. Merge Sales Data with Sell Prices

# %%
final_data = sales_calendar.merge(
    prices,
    on=["store_id", "item_id", "wm_yr_wk"],
    how="left"
)

# %%
# ==========================================================
# Display first five rows of the final merged dataset
# ==========================================================

final_data.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d  sales       date  wm_yr_wk  ... month  year  event_name_1  \
# 0       CA  d_1      0 2011-01-29     11101  ...     1  2011           NaN
# 1       CA  d_1      0 2011-01-29     11101  ...     1  2011           NaN
# 2       CA  d_1      0 2011-01-29     11101  ...     1  2011           NaN
# 3       CA  d_1      0 2011-01-29     11101  ...     1  2011           NaN
# 4       CA  d_1      0 2011-01-29     11101  ...     1  2011           NaN
#
# ...

# %%
final_data.shape
# Out:
# (58327370, 22)

# %%
final_data.isnull().sum()
# Out:
# id                     0
# item_id                0
# dept_id                0
# cat_id                 0
# store_id               0
# state_id               0
# d                      0
# sales                  0
# date                   0
# wm_yr_wk               0
# weekday                0
# wday                   0
# month                  0
# year                   0
# event_name_1    53631910
# event_type_1    53631910
# event_name_2    58205410
# event_type_2    58205410
# snap_CA                0
# snap_TX                0
# snap_WI                0
# sell_price      12299413
# dtype: int64

# %% [markdown]
# # 27. Weekend Feature

# %%
final_data["is_weekend"] = final_data["weekday"].isin(["Saturday", "Sunday"]).astype(int)

# %%
final_data["is_weekend"].value_counts()
# Out:
# is_weekend
# 0    41618850
# 1    16708520
# Name: count, dtype: int64

# %% [markdown]
# # 28. Month Feature

# %%
final_data["month"] = final_data["date"].dt.month

# %%
final_data[["date","month"]].head()
# Out:
#         date  month
# 0 2011-01-29      1
# 1 2011-01-29      1
# 2 2011-01-29      1
# 3 2011-01-29      1
# 4 2011-01-29      1

# %%
final_data["quarter"] = final_data["date"].dt.quarter

# %%
final_data[["date","quarter"]].head()
# Out:
#         date  quarter
# 0 2011-01-29        1
# 1 2011-01-29        1
# 2 2011-01-29        1
# 3 2011-01-29        1
# 4 2011-01-29        1

# %% [markdown]
# # 29. Lag Features

# %%
final_data = final_data.sort_values(["id", "date"])

# %%
final_data["lag_7"] = final_data.groupby("id")["sales"].shift(7)

# %%
final_data["lag_28"] = final_data.groupby("id")["sales"].shift(28)

# %%
final_data[
    ["id", "date", "sales", "lag_7", "lag_28"]
].head(35)
# Out:
#                                   id       date  sales  lag_7  lag_28
# 1612     FOODS_1_001_CA_1_validation 2011-01-29      3    NaN     NaN
# 32102    FOODS_1_001_CA_1_validation 2011-01-30      0    NaN     NaN
# 62592    FOODS_1_001_CA_1_validation 2011-01-31      0    NaN     NaN
# 93082    FOODS_1_001_CA_1_validation 2011-02-01      1    NaN     NaN
# 123572   FOODS_1_001_CA_1_validation 2011-02-02      4    NaN     NaN
# 154062   FOODS_1_001_CA_1_validation 2011-02-03      2    NaN     NaN
# 184552   FOODS_1_001_CA_1_validation 2011-02-04      0    NaN     NaN
# 215042   FOODS_1_001_CA_1_validation 2011-02-05      2    3.0     NaN
# 245532   FOODS_1_001_CA_1_validation 2011-02-06      0    0.0     NaN
# 276022   FOODS_1_001_CA_1_validation 2011-02-07      0    0.0     NaN
# 306512   FOODS_1_001_CA_1_validation 2011-02-08      0    1.0     NaN
# 337002   FOODS_1_001_CA_1_validation 2011-02-09      0    4.0     NaN
# ...

# %% [markdown]
# # 30. Rolling Mean Features

# %%
final_data["rolling_mean_7"] = (
    final_data.groupby("id")["sales"]
    .transform(lambda x: x.shift(1).rolling(7).mean())
)

# %%
final_data[
    ["date", "sales", "rolling_mean_7"]
].head(15)
# Out:
#              date  sales  rolling_mean_7
# 1612   2011-01-29      3             NaN
# 32102  2011-01-30      0             NaN
# 62592  2011-01-31      0             NaN
# 93082  2011-02-01      1             NaN
# 123572 2011-02-02      4             NaN
# 154062 2011-02-03      2             NaN
# 184552 2011-02-04      0             NaN
# 215042 2011-02-05      2        1.428571
# 245532 2011-02-06      0        1.285714
# 276022 2011-02-07      0        1.285714
# 306512 2011-02-08      0        1.285714
# 337002 2011-02-09      0        1.142857
# 367492 2011-02-10      3        0.571429
# 397982 2011-02-11      1        0.714286
# 428472 2011-02-12      3        0.857143

# %% [markdown]
# # 31. Rolling Standard Deviation

# %%
final_data["rolling_std_7"] = (
    final_data.groupby("id")["sales"]
    .transform(lambda x: x.shift(1).rolling(7).std())
)

# %%
final_data[
    ["date", "sales", "rolling_std_7"]
].head(15)
# Out:
#              date  sales  rolling_std_7
# 1612   2011-01-29      3            NaN
# 32102  2011-01-30      0            NaN
# 62592  2011-01-31      0            NaN
# 93082  2011-02-01      1            NaN
# 123572 2011-02-02      4            NaN
# 154062 2011-02-03      2            NaN
# 184552 2011-02-04      0            NaN
# 215042 2011-02-05      2       1.618347
# 245532 2011-02-06      0       1.496026
# 276022 2011-02-07      0       1.496026
# 306512 2011-02-08      0       1.496026
# 337002 2011-02-09      0       1.573592
# 367492 2011-02-10      3       0.975900
# 397982 2011-02-11      1       1.253566
# 428472 2011-02-12      3       1.214986

# %% [markdown]
# # 32.  Festival Feature

# %%
final_data["is_festival"] = final_data["event_name_1"].notna().astype(int)

# %%
final_data["is_festival"].value_counts()
# Out:
# is_festival
# 0    53631910
# 1     4695460
# Name: count, dtype: int64

# %% [markdown]
# # 33. SNAP Feature

# %%
final_data["snap"] = final_data[
    ["snap_CA", "snap_TX", "snap_WI"]
].max(axis=1)

# %%
final_data["snap"].value_counts()
# Out:
# snap
# 0    29514320
# 1    28813050
# Name: count, dtype: int64

# %%
final_data["sell_price"] = (
    final_data.groupby("id")["sell_price"]
    .transform(lambda x: x.ffill())
)

# %% [markdown]
# # 34. Data for Baseline XGBoost Model

# %%
selected_ids = final_data["id"].drop_duplicates().head(100)

model_data = final_data[
    final_data["id"].isin(selected_ids)
].copy()

# %%
model_data = model_data.dropna(
    subset=[
        "lag_7",
        "lag_28",
        "rolling_mean_7",
        "rolling_std_7",
        "sell_price"
    ]
)

# %% [markdown]
# # 35. Select Features for Demand Forecasting

# %%
features = [
    "lag_7",
    "lag_28",
    "rolling_mean_7",
    "rolling_std_7",
    "sell_price",
    "month",
    "quarter",
    "is_weekend",
    "is_festival",
    "snap"
]

X = model_data[features]
y = model_data["sales"]

# %%
model_data = model_data.sort_values("date")

# Use the last 28 days as the test period
test_start = model_data["date"].max() - pd.Timedelta(days=27)

train_data = model_data[
    model_data["date"] < test_start
]

test_data = model_data[
    model_data["date"] >= test_start
]

X_train = train_data[features]
y_train = train_data["sales"]

X_test = test_data[features]
y_test = test_data["sales"]

# %% [markdown]
# # 36. Train Baseline XGBoost Model

# %%
from xgboost import XGBRegressor
xgb_model = XGBRegressor(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="reg:squarederror",
    random_state=42,
    n_jobs=-1
)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
y_pred = xgb_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# MAE: 0.7268016934394836
# RMSE: 1.3036021669425406

# %%
wape = (np.abs(y_test - y_pred).sum() / np.abs(y_test).sum()) * 100
print("WAPE:", wape)
# Out:
# WAPE: 114.39261639542026

# %%
from lightgbm import LGBMRegressor

# %%
lgbm_model = LGBMRegressor(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1,
    verbosity=-1
)

# %%
lgbm_model.fit(X_train, y_train)
# Out:
# LGBMRegressor(colsample_bytree=0.8, learning_rate=0.05, max_depth=6,
#               n_estimators=200, n_jobs=-1, random_state=42, subsample=0.8,
#               verbosity=-1)

# %%
lgbm_pred = lgbm_model.predict(X_test)

# %%
lgbm_mae = mean_absolute_error(y_test, lgbm_pred)
lgbm_rmse = np.sqrt(mean_squared_error(y_test, lgbm_pred))

print("LightGBM MAE:", lgbm_mae)
print("LightGBM RMSE:", lgbm_rmse)
# Out:
# LightGBM MAE: 0.7366922829366886
# LightGBM RMSE: 1.317171566346724

# %%
results = pd.DataFrame({
    "Model": ["XGBoost", "LightGBM"],
    "MAE": [mae, lgbm_mae],
    "RMSE": [rmse, lgbm_rmse]
})

results
# Out:
#       Model       MAE      RMSE
# 0   XGBoost  0.726802  1.303602
# 1  LightGBM  0.736692  1.317172

# %%
results.to_csv("../research/model_comparison.csv", index=False)

# %%
import torch
print(torch.__version__)
# Out:
# 2.13.0+cpu

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

lstm_features = [
    "lag_7",
    "lag_28",
    "rolling_mean_7",
    "rolling_std_7",
    "sell_price",
    "month",
    "quarter",
    "is_weekend",
    "is_festival",
    "snap"
]

train_values = train_data[lstm_features].values.astype("float32")
train_targets = train_data["sales"].values.astype("float32")

test_values = test_data[lstm_features].values.astype("float32")
test_targets = test_data["sales"].values.astype("float32")

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

train_scaled = scaler.fit_transform(train_values)
test_scaled = scaler.transform(test_values)

# %%
def create_sequences(data, targets, sequence_length=7):
    X = []
    y = []

    for i in range(sequence_length, len(data)):
        X.append(data[i-sequence_length:i])
        y.append(targets[i])

    return np.array(X), np.array(y)

X_lstm_train, y_lstm_train = create_sequences(
    train_scaled,
    train_targets,
    sequence_length=7
)

X_lstm_test, y_lstm_test = create_sequences(
    test_scaled,
    test_targets,
    sequence_length=7
)

print("Training shape:", X_lstm_train.shape)
print("Testing shape:", X_lstm_test.shape)
# Out:
# Training shape: (172099, 7, 10)
# Testing shape: (2793, 7, 10)

# %%
X_lstm_train_tensor = torch.tensor(X_lstm_train, dtype=torch.float32)
y_lstm_train_tensor = torch.tensor(y_lstm_train, dtype=torch.float32)

X_lstm_test_tensor = torch.tensor(X_lstm_test, dtype=torch.float32)
y_lstm_test_tensor = torch.tensor(y_lstm_test, dtype=torch.float32)

# %%
train_dataset = TensorDataset(
    X_lstm_train_tensor,
    y_lstm_train_tensor
)

train_loader = DataLoader(
    train_dataset,
    batch_size=64,
    shuffle=False
)

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size):
        super().__init__()

        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=64,
            num_layers=2,
            batch_first=True,
            dropout=0.2
        )

        self.fc = nn.Linear(64, 1)

    def forward(self, x):
        output, _ = self.lstm(x)
        output = output[:, -1, :]
        output = self.fc(output)

        return output.squeeze()

# %%
lstm_model = LSTMModel(
    input_size=len(lstm_features)
)

criterion = nn.MSELoss()

optimizer = torch.optim.Adam(
    lstm_model.parameters(),
    lr=0.001
)

# %%
lstm_model.eval()

with torch.no_grad():
    lstm_pred = lstm_model(X_lstm_test_tensor).numpy()

# %%
lstm_mae = mean_absolute_error(
    y_lstm_test,
    lstm_pred
)

lstm_rmse = np.sqrt(
    mean_squared_error(
        y_lstm_test,
        lstm_pred
    )
)

print("LSTM MAE:", lstm_mae)
print("LSTM RMSE:", lstm_rmse)
# Out:
# LSTM MAE: 0.8739582896232605
# LSTM RMSE: 1.4910460095486464

# %%
comparison = pd.DataFrame({
    "Model": [
        "XGBoost",
        "LightGBM",
        "LSTM"
    ],
    "MAE": [
        mae,
        lgbm_mae,
        lstm_mae
    ],
    "RMSE": [
        rmse,
        lgbm_rmse,
        lstm_rmse
    ]
})

comparison
# Out:
#       Model       MAE      RMSE
# 0   XGBoost  0.726802  1.303602
# 1  LightGBM  0.736692  1.317172
# 2      LSTM  0.873958  1.491046

# %%
comparison.to_csv(
    "../research/model_comparison.csv",
    index=False
)

# %%
import shap

# %%
explainer = shap.TreeExplainer(xgb_model)

# %%
shap_values = explainer.shap_values(X_test)

# %%
shap.summary_plot(shap_values, X_test)

# %%
shap.force_plot(
    explainer.expected_value,
    shap_values[0],
    X_test.iloc[0],
    matplotlib=True
)

# %%
lead_time_days = 7
service_level_z = 1.65

# %%
decision_data = test_data.copy()

decision_data["predicted_demand"] = y_pred

decision_data["demand_std"] = decision_data["rolling_std_7"].fillna(0)

# %%
decision_data["safety_stock"] = (
    service_level_z *
    decision_data["demand_std"] *
    np.sqrt(lead_time_days)
)

# %%
decision_data["reorder_point"] = (
    decision_data["predicted_demand"] * lead_time_days
    + decision_data["safety_stock"]
)

# %%
decision_data["current_inventory"] = (
    decision_data["predicted_demand"] * 1.2
)

# %%
decision_data["stockout_risk"] = np.where(
    decision_data["current_inventory"] < decision_data["reorder_point"],
    "HIGH",
    "LOW"
)

# %%
decision_data["recommended_order"] = np.maximum(
    decision_data["reorder_point"]
    - decision_data["current_inventory"],
    0
)

# %%
decision_data[
    [
        "id",
        "date",
        "predicted_demand",
        "current_inventory",
        "safety_stock",
        "reorder_point",
        "recommended_order",
        "stockout_risk"
    ]
].head(20)
# Out:
#                                    id       date  predicted_demand  \
# 57478318  FOODS_1_009_CA_2_validation 2016-03-28          0.120561
# 57481361  FOODS_1_002_CA_3_validation 2016-03-28          0.622990
# 57481367  FOODS_1_009_CA_3_validation 2016-03-28          0.123185
# 57496605  FOODS_1_001_WI_1_validation 2016-03-28          0.673777
# 57487464  FOODS_1_008_TX_1_validation 2016-03-28          0.203548
# 57478319  FOODS_1_010_CA_2_validation 2016-03-28          0.311638
# 57484417  FOODS_1_010_CA_4_validation 2016-03-28          0.097308
# 57499657  FOODS_1_004_WI_2_validation 2016-03-28          0.332792
# 57481366  FOODS_1_008_CA_3_validation 2016-03-28          0.129745
# 57481363  FOODS_1_004_CA_3_validation 2016-03-28          1.084810
# 57475265  FOODS_1_004_CA_1_validation 2016-03-28          0.272706
# 57484412  FOODS_1_004_CA_4_validation 2016-03-28          0.272706
# 57493564  FOODS_1_010_TX_3_validation 2016-03-28          0.665074
# ...

# %%
risk_ratio = (
    decision_data["reorder_point"]
    - decision_data["current_inventory"]
) / decision_data["reorder_point"].replace(0, np.nan)

decision_data["risk_score"] = (
    risk_ratio.clip(lower=0) * 100
).fillna(0)

# %%
decision_data["risk_level"] = pd.cut(
    decision_data["risk_score"],
    bins=[-np.inf, 10, 30, 60, np.inf],
    labels=["LOW", "MEDIUM", "HIGH", "CRITICAL"]
)

# %%
decision_data["recommendation"] = np.select(
    [
        decision_data["risk_level"] == "CRITICAL",
        decision_data["risk_level"] == "HIGH",
        decision_data["risk_level"] == "MEDIUM"
    ],
    [
        "Urgent stock replenishment required",
        "Reorder stock soon",
        "Monitor inventory closely"
    ],
    default="Inventory level is adequate"
)

# %%
decision_data[
    [
        "id",
        "date",
        "predicted_demand",
        "current_inventory",
        "reorder_point",
        "recommended_order",
        "risk_score",
        "risk_level",
        "recommendation"
    ]
].head(20)
# Out:
#                                    id       date  predicted_demand  \
# 57478318  FOODS_1_009_CA_2_validation 2016-03-28          0.120561
# 57481361  FOODS_1_002_CA_3_validation 2016-03-28          0.622990
# 57481367  FOODS_1_009_CA_3_validation 2016-03-28          0.123185
# 57496605  FOODS_1_001_WI_1_validation 2016-03-28          0.673777
# 57487464  FOODS_1_008_TX_1_validation 2016-03-28          0.203548
# 57478319  FOODS_1_010_CA_2_validation 2016-03-28          0.311638
# 57484417  FOODS_1_010_CA_4_validation 2016-03-28          0.097308
# 57499657  FOODS_1_004_WI_2_validation 2016-03-28          0.332792
# 57481366  FOODS_1_008_CA_3_validation 2016-03-28          0.129745
# 57481363  FOODS_1_004_CA_3_validation 2016-03-28          1.084810
# 57475265  FOODS_1_004_CA_1_validation 2016-03-28          0.272706
# 57484412  FOODS_1_004_CA_4_validation 2016-03-28          0.272706
# 57493564  FOODS_1_010_TX_3_validation 2016-03-28          0.665074
# ...

# %%
decision_data.to_csv(
    "../research/decision_engine_results.csv",
    index=False
)

# %%
def run_price_scenario(data, price_change):

    scenario = data.copy()

    scenario["scenario_price"] = (
        scenario["sell_price"] * (1 + price_change)
    )

    scenario["scenario_predicted_demand"] = (
        xgb_model.predict(
            scenario[features].assign(
                sell_price=scenario["scenario_price"]
            )
        )
    )

    scenario["current_revenue"] = (
        scenario["sell_price"] *
        scenario["predicted_demand"]
    )

    scenario["scenario_revenue"] = (
        scenario["scenario_price"] *
        scenario["scenario_predicted_demand"]
    )

    scenario["revenue_change"] = (
        scenario["scenario_revenue"]
        - scenario["current_revenue"]
    )

    return scenario

# %%
price_down_10 = run_price_scenario(
    decision_data,
    -0.10
)

# %%
price_up_10 = run_price_scenario(
    decision_data,
    0.10
)

# %%
scenario_comparison = pd.DataFrame({
    "Current Demand": decision_data["predicted_demand"],
    "Price -10% Demand": price_down_10["scenario_predicted_demand"],
    "Price +10% Demand": price_up_10["scenario_predicted_demand"],
    "Current Revenue": decision_data["current_inventory"] * 0 + decision_data["sell_price"] * decision_data["predicted_demand"],
    "Price -10% Revenue": price_down_10["scenario_revenue"],
    "Price +10% Revenue": price_up_10["scenario_revenue"]
})

scenario_comparison.head(20)
# Out:
#           Current Demand  Price -10% Demand  Price +10% Demand  \
# 57478318        0.120561           0.123185           0.080493
# 57481361        0.622990           0.622990           0.622990
# 57481367        0.123185           1.103013           0.123185
# 57496605        0.673777           0.676401           0.626314
# 57487464        0.203548           0.168876           0.203548
# 57478319        0.311638           0.311638           0.313341
# 57484417        0.097308           0.097308           0.097308
# 57499657        0.332792           0.584845           0.245155
# 57481366        0.129745           0.086862           0.129745
# 57481363        1.084810           1.266997           1.084810
# 57475265        0.272706           0.630571           0.123185
# 57484412        0.272706           0.630571           0.123185
# 57493564        0.665074           0.629883           0.657304
# 57487463        1.099937           1.105954           1.099937
# ...

# %%
print(
    "Current Revenue:",
    decision_data["sell_price"].mul(
        decision_data["predicted_demand"]
    ).sum()
)

print(
    "Revenue with -10% Price:",
    price_down_10["scenario_revenue"].sum()
)

print(
    "Revenue with +10% Price:",
    price_up_10["scenario_revenue"].sum()
)
# Out:
# Current Revenue: 6874.053384650126
# Revenue with -10% Price: 6361.129460475951
# Revenue with +10% Price: 7408.078449377321

# %%
price_down_10.to_csv(
    "../research/price_down_10_results.csv",
    index=False
)

price_up_10.to_csv(
    "../research/price_up_10_results.csv",
    index=False
)

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

# %%
from src.forecasting.xgboost_model import train_xgboost, predict_xgboost
from src.forecasting.evaluation import calculate_metrics

# %%
test_model = train_xgboost(X_train, y_train)
test_prediction = predict_xgboost(test_model, X_test)
test_metrics = calculate_metrics(y_test, test_prediction)

test_metrics
# Out:
# {'MAE': 0.7268016934394836,
#  'RMSE': 1.3036021669425406,
#  'WAPE': 114.39261639542026}

# %%
from src.forecasting.lightgbm_model import train_lightgbm, predict_lightgbm
from src.forecasting.evaluation import calculate_metrics

test_lgbm_model = train_lightgbm(X_train, y_train)
test_lgbm_prediction = predict_lightgbm(test_lgbm_model, X_test)

test_lgbm_metrics = calculate_metrics(
    y_test,
    test_lgbm_prediction
)

test_lgbm_metrics
# Out:
# {'MAE': 0.7366922829366886,
#  'RMSE': 1.317171566346724,
#  'WAPE': 115.94931940543722}

# %%
from src.forecasting.lstm_model import train_lstm, predict_lstm
from src.forecasting.evaluation import calculate_metrics

test_lstm_model = train_lstm(
    X_lstm_train,
    y_lstm_train,
    input_size=X_lstm_train.shape[2]
)

test_lstm_prediction = predict_lstm(
    test_lstm_model,
    X_lstm_test
)

test_lstm_metrics = calculate_metrics(
    y_lstm_test,
    test_lstm_prediction
)

test_lstm_metrics
# Out:
# {'MAE': 0.9580087065696716,
#  'RMSE': 1.5030380319033516,
#  'WAPE': 150.49034118652344}

# %%
from pathlib import Path

path = Path("../src/forecasting/evaluation.py")

print(path.resolve())
print(path.exists())
print(path.read_text())
# Out:
# C:\Users\raghu vamshi\Desktop\RetailSense_AI\src\forecasting\evaluation.py
# True
# import numpy as np
# import pandas as pd
# from sklearn.metrics import mean_absolute_error, mean_squared_error
#
#
# def calculate_metrics(y_true, y_pred):
#     mae = mean_absolute_error(y_true, y_pred)
#     rmse = np.sqrt(mean_squared_error(y_true, y_pred))
#     wape = (
#         np.abs(y_true - y_pred).sum()
#         / np.abs(y_true).sum()
#     ) * 100
#
#     return {
#         "MAE": float(mae),
#         "RMSE": float(rmse),
#         "WAPE": float(wape)
#     }
#
#
# def create_model_comparison(
#     xgb_metrics,
#     lgbm_metrics,
#     lstm_metrics
# ):
#     results = pd.DataFrame([
#         {
#             "Model": "XGBoost",
#             **xgb_metrics
#         },
#         {
#             "Model": "LightGBM",
#             **lgbm_metrics
#         },
#         {
#             "Model": "LSTM",
#             **lstm_metrics
#         }
#     ])
#
#     return results.sort_values(
# ...

# %%
import sys
import importlib

sys.path.insert(0, r"C:\Users\raghu vamshi\Desktop\RetailSense_AI")

import src.forecasting.evaluation as evaluation

importlib.reload(evaluation)

print(hasattr(evaluation, "create_model_comparison"))
# Out:
# True

# %%
model_comparison = evaluation.create_model_comparison(
    test_metrics,
    test_lgbm_metrics,
    test_lstm_metrics
)

model_comparison
# Out:
#       Model       MAE      RMSE        WAPE
# 0   XGBoost  0.726802  1.303602  114.392616
# 1  LightGBM  0.736692  1.317172  115.949319
# 2      LSTM  0.958009  1.503038  150.490341

# %%
evaluation.save_model_comparison(
    model_comparison,
    "../research/model_comparison.csv"
)

# %%
from src.explainability.shap_explainer import (
    create_explainer,
    calculate_shap_values,
    get_feature_importance
)

# %%
shap_explainer = create_explainer(test_model)

shap_values = calculate_shap_values(
    shap_explainer,
    X_test
)

# %%
feature_importance = get_feature_importance(
    shap_values,
    X_test
)

feature_importance
# Out:
# {'rolling_mean_7': 0.744529664516449,
#  'sell_price': 0.22084252536296844,
#  'rolling_std_7': 0.1425834596157074,
#  'lag_28': 0.06453241407871246,
#  'is_weekend': 0.060076866298913956,
#  'lag_7': 0.05506076291203499,
#  'snap': 0.02205696515738964,
#  'month': 0.01625998690724373,
#  'is_festival': 0.0011075242655351758,
#  'quarter': 0.0004288970085326582}
